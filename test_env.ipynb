# %%
# %load_ext autoreload
# %autoreload 2

# %%
from factory_gym.factorygym import FactoryGym
from factory_gym.factorysim import FactorySimulation
from stable_baselines3 import PPO, SAC
from stable_baselines3.common.env_checker import check_env

# %%
env = FactoryGym()

# Initialize the environment and get the initial state
state = env.reset(42)
max_iter = 1000

# %%
print(check_env(env))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 check_env(env)
#
# File c:\Users\Joaquin\miniconda3\envs\agienv\Lib\site-packages\stable_baselines3\common\env_checker.py:444, in check_env(env, warn, skip_render_check)
#     439         warnings.warn(
#     440             f"Your action space has dtype {action_space.dtype}, we recommend using np.float32 to avoid cast errors."
#     441         )
#     443 # ============ Check the returned values ===============
# --> 444 _check_returned_values(env, observation_space, action_space)
#     446 # ==== Check the render method and the declared render modes ====
#     447 if not skip_render_check:
#
# File c:\Users\Joaquin\miniconda3\envs\agienv\Lib\site-packages\stable_baselines3\common\env_checker.py:256, in _check_returned_values(env, observation_space, action_space)
#     252 """
#     253 Check the returned values by the env when calling `.reset()` or `.step()` methods.
#     254 """
#     255 # because env inherits from gymnasium.Env, we assume that `reset()` and `step()` methods exists
# --> 256 reset_returns = env.reset()
#     257 assert isinstance(reset_returns, tuple), "`reset()` must return a tuple (obs, info)"
#     258 assert len(reset_returns) == 2, f"`reset()` must return a tuple of size 2 (obs, info), not {len(reset_returns)}"
#
# TypeError: FactoryGym.reset() missing 1 required positional argument: 'seed'

# %%
env.close()

# %%
env = FactoryGym()

# Initialize the PPO model
model = SAC("MultiInputPolicy", env, verbose=1)

# Train the model
model.learn(total_timesteps=10000)

model.save("test.zip")
env.close()
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
env = FactoryGym()
model = SAC("MultiInputPolicy", env,  verbose=1)
model.load("test.zip")
# Run the environment
state, info = env.reset(42)
for _ in range(0, max_iter):
    env.render()
    action, _states = model.predict(state)
    print(action)
    state, reward, done, truncated, info = env.step(action)

    # Check if the episode is done
    if done:
        print("Episode finished.")
        break

# Close the environment
env.close()
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# [0.980919]
# [8.845116]
# [4.7260704]
# [1.5461373]
# [0.08121675]
# [5.0310745]
# [6.0481057]
# [2.3867888]
# [2.5103047]
# [0.5418854]
# [0.65502656]
# [7.630997]
# [3.3456807]
# [6.4766793]
# [2.7480524]
# [2.4553576]
# [4.308009]
# [2.7901669]
# [6.82415]
# [3.9707506]
# [2.7598317]
# [5.1913934]
# [6.5726466]
# [0.31289282]
# [3.6723492]
# [1.8240182]
# [7.9879518]
# [4.743527]
# [4.450034]
# [6.2788377]
# [3.6800745]
# [7.749224]
# [6.7855444]
# [8.219109]
# [7.661237]
# [7.9947085]
# [1.3392473]
# [7.649861]
# [8.831516]
# [5.2638574]
# [5.882221]
# [2.7208245]
# [2.051887]
# [5.425378]
# [5.568927]
# [0.2688496]
# [1.5335739]
# [8.648858]
# [2.2602105]
# [8.531974]
# [8.192279]
# [4.8151083]
# [8.043792]
# [8.79865]
# [4.7618856]
# [3.998627]
# [0.5347754]
# [4.1207643]
# [8.244298]
# [7.552619]
# [8.923965]
# [0.6238172]
# [7.2748504]
# [8.264839]
# [8.108305]
# [8.7849865]
# [1.3370206]
# [6.384717]
# [0.51945215]
# [2.2524347]
# [2.171253]
# [4.768588]
# [4.6233516]
# [0.4127866]
# [6.416073]
# [2.1255577]
# [1.3785803]
# [7.779448]
# [8.832763]
# [3.7488394]
# [2.0135186]
# [8.074197]
# [0.927193]
# [0.49248844]
# [7.756609]
# [8.5759735]
# [0.13351044]
# [8.331307]
# [0.6269508]
# [2.7101862]
# [0.3904953]
# [7.5370607]
# [1.4256381]
# [0.35821438]
# [8.502196]
# [1.5694292]
# [2.1629963]
# [0.7307831]
# [3.2460575]
# [2.658323]
# [3.4752505]
# [4.3751597]
# [6.458416]
# [3.318332]
# [1.0184994]
# [0.10250947]
# [7.6479883]
# [2.8608222]
# [7.3638864]
# [1.1088085]
# [7.177433]
# [6.135126]
# [3.1997514]
# [1.9209691]
# [8.048433]
# [4.303545]
# [7.5231934]
# [4.262752]
# [8.731797]
# [3.5479913]
# [0.6340444]
# [7.14824]
# [8.618175]
# [7.8171997]
# [7.073071]
# [6.5150847]
# [4.1965947]
# [1.4724791]
# [8.07134]
# [0.6204089]
# [8.585838]
# [7.8954225]
# [1.9937971]
# [7.2002897]
# [7.4044476]
# [0.5429676]
# [8.221878]
# [4.404128]
# [2.242196]
# [1.9456124]
# [5.6801076]
# [1.3578863]
# [1.9087975]
# [6.85053]
# [0.8044245]
# [0.53656495]
# [7.083107]
# [8.33017]
# [4.7874775]
# [1.5180318]
# [5.5810547]
# [0.22617137]
# [7.676283]
# [1.1089789]
# [0.40439987]
# [3.4919481]
# [5.886546]
# [4.5727744]
# [3.4372036]
# [2.7565117]
# [8.927135]
# [5.6579475]
# [7.3096237]
# [3.440574]
# [2.6845531]
# [2.5379157]
# [0.7176969]
# [2.1515787]
# [7.4852276]
# [1.3635964]
# [2.5718699]
# [0.3553337]
# [3.1433704]
# [8.355134]
# [2.774446]
# [6.1170583]
# [5.073401]
# [7.2622123]
# [1.0826799]
# [6.1519885]
# [5.818898]
# [5.037108]
# [8.494065]
# [7.6668515]
# [6.8616323]
# [3.0452745]
# [3.7272398]
# [0.864535]
# [1.9061891]
# [5.6359053]
# [1.5482166]
# [1.5164341]
# [4.2346916]
# [6.307399]
# [4.200609]
# [4.888154]
# [8.945521]
# [8.86959]
# [7.7828703]
# [8.407685]
# [7.3623214]
# [4.9177494]
# [8.16542]
# [1.2023498]
# [7.5987864]
# [8.7438755]
# [5.505848]
# [7.2092743]
# [5.9516068]
# [8.877565]
# [1.7185286]
# [3.0621927]
# [8.980751]
# [1.1774434]
# [3.080247]
# [5.3274775]
# [8.744163]
# [4.2218504]
# [6.0879827]
# [3.674229]
# [0.40320736]
# [0.3928114]
# [2.8934364]
# [6.2059884]
# [7.950763]
# [2.6919708]
# [7.058638]
# [5.888448]
# [4.2496424]
# [0.5068251]
# [8.367362]
# [0.6609961]
# [7.6424513]
# [2.135792]
# [0.40001285]
# [5.825638]
# [6.947132]
# [2.2564473]
# [3.122866]
# [7.7098]
# [0.8746413]
# [5.35878]
# [2.5032585]
# [2.472795]
# [4.0057516]
# [1.6259143]
# [2.7534935]
# [8.900426]
# [4.52181]
# [4.0080104]
# [0.41414192]
# [8.6191435]
# [5.689513]
# [8.692088]
# [6.3642173]
# [4.9528637]
# [2.4180157]
# [4.7370644]
# [4.824016]
# [6.7303123]
# [1.170383]
# [6.141371]
# [3.3512182]
# [4.75412]
# [1.210747]
# [1.1948452]
# [0.8318099]
# [1.0138001]
# [4.931012]
# [7.169608]
# [8.459591]
# [5.4532204]
# [1.8476038]
# [4.8496065]
# [6.900289]
# [3.1578507]
# [4.028664]
# [8.360487]
# [7.6363444]
# [2.7158198]
# [8.627161]
# [1.521936]
# [0.58123094]
# [4.1878624]
# [4.795838]
# [0.2542297]
# [6.1271696]
# [7.0220413]
# [3.6313868]
# [2.1951551]
# [8.26152]
# [7.8660264]
# [3.997007]
# [6.91359]
# [1.1015629]
# [6.508776]
# [7.354914]
# [8.740289]
# [4.402282]
# [7.4837966]
# [7.53948]
# [1.2692046]
# [7.5814166]
# [1.8037952]
# [6.1839724]
# [8.538211]
# [0.20363465]
# [8.4266815]
# [8.879841]
# [2.8088372]
# [6.487671]
# [4.3106127]
# [7.268701]
# [3.7468905]
# [1.3003513]
# [8.170033]
# [1.3338041]
# [2.1574538]
# [5.794095]
# [3.1117787]
# [8.459864]
# [1.4733176]
# [4.4766016]
# [3.0503502]
# [0.9998905]
# [4.0088153]
# [3.2457318]
# [1.1143639]
# [8.655318]
# [8.469813]
# [6.07028]
# [3.0084505]
# [5.454262]
# [4.6064935]
# [6.7553473]
# [7.367123]
# [6.771743]
# [3.1062539]
# [0.98497957]
# [6.7201967]
# [4.2350345]
# [1.3580673]
# [7.571191]
# [3.002687]
# [0.897428]
# [3.5696056]
# [7.6360693]
# [5.120051]
# [4.8211484]
# [0.6345661]
# [6.5209394]
# [7.587669]
# [1.2491807]
# [1.7583243]
# [1.4198225]
# [5.2182307]
# [4.1719027]
# [2.100976]
# [6.584714]
# [3.2810137]
# [4.3273435]
# [6.059776]
# [7.3546867]
# [1.8873842]
# [2.4168901]
# [5.307606]
# [2.705497]
# [8.708587]
# [1.2537235]
# [5.485631]
# [0.12997422]
# [7.8215504]
# [8.522012]
# [5.517382]
# [8.282597]
# [5.8324375]
# [5.8911314]
# [5.368861]
# [5.8941708]
# [8.028775]
# [3.9560926]
# [6.9958377]
# [2.3042116]
# [5.7844424]
# [0.3543654]
# [0.13405117]
# [1.4056122]
# [8.696772]
# [8.068671]
# [0.7425524]
# [4.058325]
# [1.4122279]
# [6.843461]
# [7.43363]
# [8.749162]
# [8.031721]
# [6.656166]
# [6.74034]
# [6.5631423]
# [3.284881]
# [8.229155]
# [8.675492]
# [8.513198]
# [7.953111]
# [4.6473765]
# [6.2328634]
# [6.29817]
# [6.862341]
# [6.317395]
# [8.843287]
# [3.8707387]
# [5.4192276]
# [8.651048]
# [5.6391187]
# [6.0057673]
# [4.524025]
# [8.890554]
# [3.0772958]
# [7.5728827]
# [4.1331615]
# [2.7163534]
# [8.339777]
# [0.8679902]
# [3.8773544]
# [7.3173976]
# [0.36059484]
# [8.743776]
# [7.575347]
# [1.9238209]
# [2.3680532]
# [0.32436892]
# [2.2340844]
# [8.810338]
# [3.1005805]
# [7.729725]
# [2.6279447]
# [6.1203547]
# [1.1394093]
# [8.274288]
# [4.317128]
# [7.1847367]
# [8.478882]
# [2.280524]
# [8.567744]
# [5.8265886]
# [7.8872375]
# [6.096917]
# [4.161327]
# [2.1729476]
# [2.7657545]
# [7.7924137]
# [5.3590946]
# [7.2565994]
# [1.0702553]
# [6.1081467]
# [1.4556236]
# [2.1904235]
# [7.0900702]
# [3.5581918]
# [3.9765077]
# [7.933777]
# [5.078032]
# [7.787428]
# [1.0579431]
# [0.24292177]
# [1.6719722]
# [7.3097715]
# [2.9540663]
# [7.8443427]
# [4.725705]
# [2.4797602]
# [7.7711825]
# [6.08447]
# [8.045559]
# [8.243145]
# [3.8748825]
# [2.150249]
# [0.846569]
# [6.978195]
# [7.442485]
# [0.77216184]
# [5.6019926]
# [8.578022]
# [0.5893787]
# [5.3584824]
# [0.66967595]
# [2.368109]
# [4.07733]
# [7.4712114]
# [2.789489]
# [1.9410286]
# [7.290713]
# [7.1301737]
# [3.1219237]
# [4.178539]
# [0.85592854]
# [5.948918]
# [8.383377]
# [6.5334387]
# [4.5601864]
# [8.4258995]
# [5.919803]
# [0.39966497]
# [8.923723]
# [5.4644623]
# [2.9746943]
# [6.8974457]
# [0.12539595]
# [1.2746003]
# [1.4172788]
# [4.697634]
# [0.6946857]
# [2.4964728]
# [3.755822]
# [1.9413676]
# [7.9920096]
# [1.3851962]
# [8.376242]
# [0.3365923]
# [8.694382]
# [8.832854]
# [7.744418]
# [8.191373]
# [7.8460646]
# [1.947546]
# [2.1652162]
# [2.3542361]
# [1.431419]
# [1.8115699]
# [5.980553]
# [5.7132683]
# [6.0738344]
# [6.9273424]
# [7.647334]
# [1.6092937]
# [7.6398754]
# [8.765136]
# [2.1915073]
# [7.8646803]
# [4.537094]
# [1.9662077]
# [0.0540221]
# [2.3383145]
# [1.5817748]
# [5.0241547]
# [7.246075]
# [0.25528836]
# [1.2396681]
# [8.248235]
# [2.9598267]
# [8.593672]
# [6.6696057]
# [6.8282413]
# [8.864548]
# [4.819652]
# [0.6840311]
# [8.331139]
# [3.1223454]
# [8.600228]
# [7.260991]
# [1.3204777]
# [4.6359315]
# [8.984627]
# [5.5219917]
# [2.6560378]
# [6.030061]
# [5.525506]
# [5.6602335]
# [6.1391654]
# [0.43130484]
# [5.665287]
# [0.26632914]
# [4.2811737]
# [8.517031]
# [7.360742]
# [4.1073246]
# [7.627821]
# [7.8658214]
# [3.21333]
# [0.719082]
# [6.5976753]
# [4.623497]
# [0.2780713]
# [0.7052512]
# [6.063085]
# [8.924271]
# [5.6760244]
# [3.479481]
# [0.7558009]
# [8.473175]
# [3.3963099]
# [5.8505845]
# [6.505937]
# [4.853981]
# [5.4677052]
# [5.7634006]
# [0.32006425]
# [8.537443]
# [3.3818445]
# [7.8166614]
# [7.517383]
# [0.6676297]
# [5.838917]
# [8.133959]
# [0.50763834]
# [3.844496]
# [3.0529556]
# [4.6047297]
# [3.3814247]
# [7.529764]
# [7.568378]
# [8.113191]
# [0.7121399]
# [2.4150722]
# [0.73345435]
# [8.220659]
# [8.345908]
# [1.375897]
# [8.715218]
# [3.0822966]
# [3.7284482]
# [0.17393106]
# [7.157506]
# [2.9015753]
# [4.685606]
# [8.379585]
# [1.5253897]
# [8.890035]
# [1.7581998]
# [4.1753016]
# [5.1118402]
# [7.9618273]
# [2.4509118]
# [6.6350083]
# [3.7690973]
# [4.0841193]
# [8.671426]
# [7.609842]
# [3.9015932]
# [0.53801274]
# [2.9029982]
# [8.607594]
# [5.3036575]
# [0.26402566]
# [5.65833]
# [5.601081]
# [7.1639185]
# [1.1284928]
# [8.078023]
# [7.0194535]
# [2.0037804]
# [7.9045033]
# [8.735572]
# [3.349058]
# [8.927416]
# [4.8904185]
# [8.678041]
# [7.02214]
# [8.929073]
# [1.9095002]
# [6.3208475]
# [8.85365]
# [8.258697]
# [8.716272]
# [5.018766]
# [1.6905698]
# [6.8437905]
# [1.2072387]
# [4.414856]
# [1.2247949]
# [0.0566563]
# [1.0914649]
# [5.760872]
# [6.5540047]
# [2.3973417]
# [1.79055]
# [7.7103124]
# [2.1507468]
# [2.0604863]
# [3.3104765]
# [5.801915]
# [3.598983]
# [2.432917]
# [7.646642]
# [7.7974844]
# [4.727882]
# [4.8161225]
# [2.9441075]
# [7.7226753]
# [2.1666138]
# [0.7510239]
# [0.16284469]
# [1.7293347]
# [5.2862263]
# [1.0555863]
# [1.3037115]
# [8.762367]
# [8.400767]
# [0.43726766]
# [8.942132]
# [0.6198046]
# [8.809141]
# [8.920473]
# [6.774617]
# [5.160397]
# [0.54092884]
# [1.4417129]
# [0.19183132]
# [1.5697317]
# [6.882128]
# [1.9100959]
# [5.6751466]
# [7.3297205]
# [0.46187103]
# [7.230561]
# [8.256364]
# [3.6575913]
# [4.463506]
# [3.8406594]
# [8.341552]
# [8.782104]
# [7.799413]
# [7.0125403]
# [2.8434012]
# [8.245823]
# [8.009456]
# [5.2156115]
# [2.4832225]
# [8.008663]
# [6.207263]
# [0.04315326]
# [3.236723]
# [7.074217]
# [0.6714119]
# [6.492982]
# [8.629718]
# [8.9529915]
# [3.3245792]
# [3.4205225]
# [6.575059]
# [4.785743]
# [7.3677883]
# [1.2902219]
# [4.4285927]
# [1.9298575]
# [4.0530868]
# [4.1407037]
# [3.4668279]
# [8.179571]
# [1.52016]
# [8.308963]
# [0.21544173]
# [1.2092559]
# [6.4093647]
# [5.528727]
# [7.8173]
# [7.409597]
# [2.6653657]
# [3.6987185]
# [3.505944]
# [8.746965]
# [0.46564463]
# [7.74636]
# [1.400428]
# [7.3865366]
# [4.7173133]
# [0.9540789]
# [4.6463614]
# [0.33628598]
# [8.806913]
# [7.7715406]
# [3.1446528]
# [4.892211]
# [2.7342093]
# [4.017085]
# [3.662176]
# [2.2722683]
# [7.9655304]
# [2.879699]
# [7.1145935]
# [8.658206]
# [4.893268]
# [5.689692]
# [1.9546442]
# [5.68037]
# [6.280266]
# [0.21842676]
# [8.178876]
# [2.937049]
# [7.6810384]
# [6.8776994]
# [3.7672117]
# [4.2532587]
# [0.32785258]
# [5.437382]
# [5.8740716]
# [0.04933977]
# [1.7824416]
# [6.581329]
# [5.9151173]
# [7.8075237]
# [6.533637]
# [7.3757286]
# [8.633153]
# [5.9244366]
# [1.4300272]
# [1.9653584]
# [8.086527]
# [0.10713011]
# [7.39504]
# [0.0984942]
# [5.210816]
# [1.7499166]
# [7.481614]
# [6.501487]
# [5.809148]
# [0.65210724]
# [1.0466361]
# [4.4324584]
# [5.8993306]
# [8.987145]
# [5.203863]
# [0.07541272]
# [2.01211]
# [1.0613484]
# [0.757462]
# [5.2806177]
# [4.9021726]
# [4.2862835]
# [0.4990105]
# [3.3929276]
# [5.0804386]
# [8.880454]
# [0.9648496]
# [7.231237]
# [8.845023]
# [6.4615664]
# [7.722856]
# [5.5011163]
# [8.327421]
# [8.600033]
# [5.5923185]
# [8.966947]
# [2.3927698]
# [5.4576697]
# [8.390699]
# [8.425532]
# [1.6886568]
# [5.431167]
# [6.0227942]
# [4.862997]
# [6.45938]
# [6.5826273]
# [7.7788234]
# [8.220382]
# [8.378083]
# [5.9756727]
# [3.4481318]
# [6.9192996]
# [2.3516831]
# [3.9757574]
# [7.402312]
# [7.919655]
# [4.430882]
# [5.301924]
# [8.139659]
# [5.9803634]
# [6.2949934]
# [2.3892987]
# [7.891099]
# [1.6056744]
# [1.3859307]
# [4.585649]
# [0.77647805]
# [0.01518774]
# [8.1363]
# [4.905531]
# [2.7820814]
# [1.1512861]
# [4.0581765]
# [7.6289353]
# [8.007418]
# [0.632161]
# [1.98085]
# [3.4507189]
# [6.2382054]
# [7.458542]
# [8.368496]
# [0.79202926]
# [8.547915]
# [2.9849415]
# [4.905905]
# [3.1985068]
# [1.0767605]
# [3.1512072]
# [8.024209]
# [5.063037]
# [0.46586484]
# [6.8713384]
# [7.3741207]
# [6.1072564]
# [8.562013]
# [8.836915]
# [3.998044]
# [7.8562236]
# [5.306684]
# [0.72600853]
# [3.0198963]
# [2.1051395]
# [6.3504143]
# [1.2420425]
# [8.662637]
# [1.1085329]
# [0.78937495]
# [1.1997762]
# [0.6623758]
# [0.6668224]
# [1.9831948]
# [8.782763]
# [2.42903]
# [8.716049]
# [5.2826095]
# [1.3670425]
# [7.639426]
# [7.192478]
# [1.9715786]
# [1.599029]
# [3.646036]
# [1.2915862]
# [0.9565943]
# [3.9955637]
# [5.2242203]
# [4.4385495]
# [4.451211]
# [0.04862818]
# [2.5163364]
# [6.325797]
# [0.7536495]
# [1.266509]
# [8.919033]
# [8.253642]
# [8.3868065]
# [8.24212]
# [4.374974]
# [6.2799582]
# [0.22455186]
# [8.463276]
# [8.14597]
# [5.7565837]
# [6.257862]
# [2.3929348]
# [3.4540517]
# [0.23250648]
# [2.021004]
# [0.86200136]
# [2.6156645]
# [8.9276285]
# [5.05736]
# [4.1544137]
# [8.283107]
# [7.507921]
# [4.226372]
# [3.8596694]
# [2.1885753]
# [2.1916246]
# [0.05194741]
# [1.145385]
# [3.1508558]
# [0.46016756]
# [6.2299275]
# [0.7527869]
# [3.0800707]
# [5.700089]
# [7.6774397]
# [8.056078]
# [0.93349296]
# [7.1867857]
# [0.22545844]
# [4.3224874]
# [0.66551024]
# [7.714565]
# [3.288456]
# [7.0182776]
# [7.7866383]
# [0.23963231]
# [8.302968]
# [1.2379441]
# [1.1369305]
# [7.4103374]
# [7.6985483]
# [4.6545453]
# [0.7902477]
# [8.968184]
# [4.0366206]
# [2.4470248]
# [4.446051]
# [8.2249565]
# [8.111141]
# [4.625664]
# [0.8295107]
